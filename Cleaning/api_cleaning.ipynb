# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plp
import numpy as np

# %%
df_2005= pd.read_csv('datos_2005.csv',sep=";")
df_2006= pd.read_csv('datos_2006.csv',sep=";")
df_2007= pd.read_csv('datos_2007.csv',sep=";")
df_2008= pd.read_csv('datos_2008.csv',sep=";")
df_2009= pd.read_csv('datos_2009.csv',sep=";")
df_2010= pd.read_csv('datos_2010.csv',sep=";")
df_2011= pd.read_csv('datos_2011.csv',sep=";")
df_2012= pd.read_csv('datos_2012.csv',sep=";")
df_2013= pd.read_csv('datos_2013.csv',sep=";")
df_2014= pd.read_csv('datos_2014.csv',sep=";")
df_2015= pd.read_csv('datos_2015.csv',sep=";")
df_2016= pd.read_csv('datos_2016.csv',sep=";")
df_2017= pd.read_csv('datos_2017.csv',sep=";")
df_2018= pd.read_csv('datos_2018.csv',sep=";")
df_2019= pd.read_csv('datos_2019.csv',sep=";")
df_2020= pd.read_csv('datos_2020.csv',sep=";")
df_2021= pd.read_csv('datos_2021.csv',sep=";")
df_2022= pd.read_csv('datos_2022.csv',sep=";")
df_2023= pd.read_csv('datos_2023.csv',sep=";")

# %%
print(df_2005.shape)
print(df_2006.shape)
print(df_2007.shape)
print(df_2008.shape)
print(df_2009.shape)
print(df_2010.shape)
print(df_2011.shape)
print(df_2012.shape)
print(df_2013.shape)
print(df_2014.shape)
print(df_2015.shape)
print(df_2016.shape)
print(df_2017.shape)
print(df_2018.shape)
print(df_2019.shape)
print(df_2020.shape)
print(df_2021.shape)
print(df_2022.shape)
print(df_2023.shape)

# %%
df = pd.concat(df_2005,df_2006,df_2007,df_2008,df_2009,df_2010,df_2011,df_2012,df_2013,df_2014,df_2015,df_2016,df_2017,df_2018,df_2019,df_2020,df_2021,df_2022,df_2023)

# %%
dfs = [df_2005, df_2006, df_2007, df_2008, df_2009, df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017, df_2018, df_2019, df_2020, df_2021, df_2022, df_2023]

df = pd.concat(dfs, axis=0)

# %%
df.dropna()
# Out:
#        provincia  municipio  estacion  magnitud  punto_muestreo   ano  mes  \
# 10            28         13         2         7    28013002_7_8  2005    1
# 11            28         13         2         8    28013002_8_8  2005    1
# 12            28         13         2        10  28013002_10_49  2005    1
# 13            28         13         2        14   28013002_14_6  2005    1
# 53            28         45         2         6   28045002_6_48  2005    1
# ...          ...        ...       ...       ...             ...   ...  ...
# 63823         28         92         5         7    28092005_7_8  2023   12
# 63824         28         92         5         8    28092005_8_8  2023   12
# 63825         28         92         5        10  28092005_10_49  2023   12
# 63826         28         92         5        12   28092005_12_8  2023   12
# 63827         28         92         5        14   28092005_14_6  2023   12
#
# ...

# %%
df=df.dropna()

# %%
df.to_csv('Datos_medioambiente')

# %%
import urllib as ur

# %%
url = 'https://datos.comunidad.madrid/catalogo/api/3/action/datastore_search?resource_id=547d610b-1bf6-4e92-b713-1c9b3a10a8e0&limit=5&q=title:jones'  
ur.fileobj = urllib.urlopen(url)

# %%
import requests

response = requests.get(url)
if response.status_code == 200:  # 200 means the request was successful
    print(response.text)  # Print the content of the response
else:
    print('Request was not successful. Status code:')

# %%
import requests

url = 'https://datos.comunidad.madrid/catalogo/api/3/action/datastore_search?resource_id=547d610b-1bf6-4e92-b713-1c9b3a10a8e0&limit=5&q=title:jones'
response = requests.get(url)

if response.status_code == 200:  # 200 means the request was successful
    print(response.text)  # Print the content of the response
else:
    print('Request was not successful. Status code:', response.status_code)
